# %% [markdown]
# # <span style="color:darkblue"> Lecture 11: Application 2 - Random Assignment </span>
#
# <font size = "5">

# %% [markdown]
# # <span style="color:darkblue"> I. Import Libraries and Data </span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
carfeatures = pd.read_csv("data_raw/features.csv")

# %% [markdown]
# # <span style="color:darkblue"> I. Random Assignment (quiz) </span>
#
# <font size = "5">
#
# Random assignment is crucial for scientific progress ...
#
# - The basis for medical trials
# - Also used in engineering, the natural sciences and <br>
#   social sciences (economics, political science, etc.)

# %%
# "list_status" is a list with "treatment/control" arms
# "prop_status" is the proportion in the treatment and control arms
# "size_dataset" is how many rows are contained

list_status  = ["Treatment","Control"]
prop_status  = [0.4,0.6]
size_dataset = len(carfeatures)

# %% [markdown]
# <font size = "5">
# Random assignment

# %%
# The "np.random.choice" will create a vector with the status
# We will save this to a column in "carfeatures"
# Note: (i) We can always split the arguments of a function in multiple lines
#           to make it easier to read

carfeatures["status"] = np.random.choice(list_status,
                                         size = size_dataset,
                                         p = prop_status)

display(carfeatures)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8           307        130    3504          12.0
# 1    15.0          8           350        165    3693          11.5
# 2    18.0          8           318        150    3436          11.0
# 3    16.0          8           304        150    3433          12.0
# 4    17.0          8           302        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4           140         86    2790          15.6
# 394  44.0          4            97         52    2130          24.6
# 395  32.0          4           135         84    2295          11.6
# 396  28.0          4           120         79    2625          18.6
# 397  31.0          4           119         82    2720          19.4
#
#     vehicle_id     status
# 0    C-1689780    Control
# 1    B-1689791  Treatment
# 2    P-1689802  Treatment
# 3    A-1689813    Control
# 4    F-1689824    Control
# ..         ...        ...
# 393  F-1694103  Treatment
# 394  V-1694114    Control
# 395  D-1694125  Treatment
# 396  F-1694136    Control
# 397  C-1694147  Treatment
#
# [398 rows x 8 columns]

# %% [markdown]
# <font size = "5">
#
# Compute frequencies by status

# %%
# The command "pd.crosstab" computes frequencies
# If we add the option "normalize" it will compute proportions
# Note: The default assignment is done randomly without replacement
#       which means that the proportions are approximately the same   
#       (but not equal) to "prop_status"

frequency_table   = pd.crosstab(index = carfeatures["status"], columns = "Frequency")
proportions_table = pd.crosstab(index = carfeatures["status"],
                                columns = "Frequency",
                                normalize = True)

display(frequency_table)
display(proportions_table)
# Out:
# col_0      Frequency
# status
# Control          251
# Treatment        147
# col_0      Frequency
# status
# Control     0.630653
# Treatment   0.369347

# %% [markdown]
# <font size = "5">
#
# Query with string conditions

# %%
# When you have queries for text variables, it's important
# to use outer ' ' single quotations
# and inner double quotations.

data_treated = carfeatures.query('status == "Treatment" ')
data_control = carfeatures.query('status == "Control" ')

# %% [markdown]
# <font size = "5">
#
# Treated/control should be similar
#
# - This is the key principle of random assignment
# - We can check the summary statistics

# %%
# The count is different because we assigned different proportions
# All other sumary statistics are approximately the same
# They are not identical because the assignment is random

display(data_treated.describe())
display(data_control.describe())
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  145.000000  145.000000    145.000000   145.000000    145.000000
# mean    23.656552    5.558621    194.965517  2999.124138     15.622069
# std      8.487383    1.735559    103.989477   862.268865      2.806626
# min      9.000000    4.000000     68.000000  1760.000000      9.500000
# 25%     17.000000    4.000000     98.000000  2200.000000     13.900000
# 50%     22.000000    4.000000    144.000000  2910.000000     15.000000
# 75%     29.900000    8.000000    302.000000  3672.000000     17.300000
# max     46.600000    8.000000    455.000000  5140.000000     24.600000
#               mpg   cylinders  displacement       weight  acceleration
# count  253.000000  253.000000    253.000000   253.000000    253.000000
# mean    23.433202    5.395257    192.545455  2953.976285     15.537154
# std      7.420168    1.681451    104.624019   839.151120      2.734372
# min     10.000000    3.000000     70.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    105.000000  2245.000000     13.800000
# 50%     23.000000    4.000000    151.000000  2735.000000     15.500000
# 75%     28.800000    6.000000    258.000000  3563.000000     17.000000
# max     44.600000    8.000000    455.000000  4997.000000     24.800000

# %% [markdown]
# ## <span style="color:darkblue"> III. Quiz Structure </span>
#
# <font size = "5">
#
# The day of the quiz I will ...
# - Provide a dataset with information
# - Give more specific instructions.
# - Below, you will see the type of questions that will be asked.
# - The idea is for you to apply known concepts to new data
# - You have 50 minutes to complete the assignment
#
# Questions
#
# (exact wording may change in quiz, but exercise will be very similar)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

carfeatures = pd.read_csv("data_raw/features.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Create a function and apply it to a column
#
# - Check Lecture 8 for how to define a function
# - The function will have if/else statements and output a string
# - You will use ".apply()" to create a new variable in the dataset <br>
# (see Lecture 9)

# %%
list_mpg     = ["mpg"]
car_mpg = carfeatures[list_mpg]
list_weight     = ["weight"]
car_weight = carfeatures[list_weight]

data = {'car_mpg','car_weight'}

df = pd.DataFrame(data)

def categorize_mpg(car_mpg,car_weight):
    if car_mpg < 18:
        return 'small'
    else:
        return 'big'
    
df['mpg_group'] = df['car_mpg'].apply(categorize_mpg)

print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/norazhou/Desktop/qtm151_fall_2023/lecture_11/lecture_11_副本.ipynb Cell 18 line 1
#      <a href='vscode-notebook-cell:/Users/norazhou/Desktop/qtm151_fall_2023/lecture_11/lecture_11_%E5%89%AF%E6%9C%AC.ipynb#X33sZmlsZQ%3D%3D?line=12'>13</a>     else:
#      <a href='vscode-notebook-cell:/Users/norazhou/Desktop/qtm151_fall_2023/lecture_11/lecture_11_%E5%89%AF%E6%9C%AC.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a>         return 'big'
# ---> <a href='vscode-notebook-cell:/Users/norazhou/Desktop/qtm151_fall_2023/lecture_11/lecture_11_%E5%89%AF%E6%9C%AC.ipynb#X33sZmlsZQ%3D%3D?line=15'>16</a> df['mpg_group'] = df['car_mpg'].apply(categorize_mpg)
#      <a href='vscode-notebook-cell:/Users/norazhou/Desktop/qtm151_fall_2023/lecture_11/lecture_11_%E5%89%AF%E6%9C%AC.ipynb#X33sZmlsZQ%3D%3D?line=17'>18</a> print(df)
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'car_mpg'

# %% [markdown]
# <font size = "5">
#
# (b) Use queries + global variables
#
# - You will be asked to compute certain summary statistics <br>
# (mean, median, etc)
# - The query will have multiple conditions
# - Then subset a dataset that meets certain conditions
# - See Lecture 10 for more details

# %%
data = {
    'Product': ['A', 'B', 'C', 'D', 'E'],
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Books', 'Electronics'],
    'Price': [500, 45, 750, 20, 300],
    'Quantity': [10, 15, 5, 30, 8]
}
df = pd.DataFrame(data)

# Define global variables for conditions
min_price = 100
min_quantity = 10

# Compute mean price for products in the 'Electronics' category with price > min_price
mean_price_electronics = df.query("Category == 'Electronics' and Price > @min_price")['Price'].mean()

# Compute median quantity for products with quantity > min_quantity
median_quantity_high_quantity = df.query("Quantity > @min_quantity")['Quantity'].median()

# Create a subset of products that meet certain conditions
subset = df.query("Category == 'Electronics' and Price > @min_price and Quantity > @min_quantity")

print("Mean price of electronics with price > $100:", mean_price_electronics)
print("Median quantity of products with quantity > 10:", median_quantity_high_quantity)
print("\nSubset of products meeting conditions:")
print(subset)
# Out:
# Mean price of electronics with price > $100: 516.6666666666666
# Median quantity of products with quantity > 10: 22.5
#
# Subset of products meeting conditions:
# Empty DataFrame
# Columns: [Product, Category, Price, Quantity]
# Index: []

# %%
car1 = carfeatures.query("cylinders > 5 & mpg > 20")
print(np.mean(car1["mpg"]))

list_subsetcols     = ["weight","mpg"]
subcols_carfeatures = car1[list_subsetcols]
display(subcols_carfeatures)
# Out:
# 23.27837837837838
#      weight   mpg
# 15     2833  22.0
# 17     2587  21.0
# 24     2648  21.0
# 101    2904  23.0
# 113    2472  21.0
# 126    2875  21.0
# 164    3039  21.0
# 191    3233  22.0
# 192    3353  22.0
# 193    3012  24.0
# 194    3085  22.5
# 226    3425  20.5
# 241    2815  22.0
# 251    3570  20.2
# 253    3155  20.5
# 254    2965  20.2
# 256    3430  20.5
# 258    3380  20.6
# 259    3070  20.8
# 280    3245  21.5
# 283    3265  20.2
# 284    3360  20.6
# 298    3900  23.0
# 300    3420  23.9
# 306    2595  28.8
# 307    2700  26.8
# 333    2910  32.7
# 341    2725  23.5
# 360    3160  30.7
# 361    2900  25.4
# 362    2930  24.2
# 363    3415  22.4
# 364    3725  26.6
# 365    3060  20.2
# 386    2945  25.0
# 387    3015  38.0
# 389    2835  22.0

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# - Extract the observations with the largest values of a column
# - See Lecture 10 for details

# %%
carfeatures_mpg = carfeatures.sort_values(by="mpg",ascending=False)
carfeatures_mpg.iloc[0:5, : ]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id
# 322  46.6          4            86         65    2110          17.9  M-1693322
# 329  44.6          4            91         67    1850          13.8  H-1693399
# 325  44.3          4            90         48    2085          21.7  V-1693355
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 326  43.4          4            90         48    2335          23.7  V-1693366

# %% [markdown]
# <font size = "5">
#
# (d) Split a dataset into subsets
#
# - You will be asked to randomly assign a status to each row
# - Split the data into separate datasets using ".query()"
# - This will closely follow the material in Lecture 12 (this one)
# - You will need this result to answer questions (e), (f)

# %% [markdown]
# <font size = "5">
#
# (e) Create a function with four inputs $f(y,x,b0,b1)$
#
# - Start by using "def" to define the function
# - The function will include arithmetic operations (Lecture 3) <br>
# and summary statistics for pandas (mean, std, min, max, etc.)
# - You will be asked to test different values of $(y,x,b0,b1)$
# - You will get $y$ and $x$ from the two datasets in part (d)
# - Note: You will **not** be required to use the "statsmodels" library

# %%
def function(x, y, b0, b1):
    V = x**2+2*y+(b0/b1)
    return V

function(1,2,8,4)
# Out:
# 7.0

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping histogram plots
#
# - You will use a variable from the two datasets in (d)
# - You need to use the "alpha" option to make the graphs semitransparent
# - You will need to add a legend, label the axes, and the title
# - Note: The goal of this question is to illustrate that random <br>
# assignment produces very similar distributions between two groups

# %%
list_unique_cylinders = pd.unique(carfeatures["cylinders"])

for category_value in list_unique_cylinders:
    temporarydataframe = carfeatures.query("cylinders == @category_value")
    plt.hist(temporarydataframe["mpg"],alpha = 0.5)

plt.legend(labels = list_unique_cylinders)
plt.title("histogram")
plt.xlabel("mpg")
plt.ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')
